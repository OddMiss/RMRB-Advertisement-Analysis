# %% [markdown]
# RMRB Analysis v5 (2025.9.17)
#
# - Reconstruct the project
# - Combine `RMRB_Online` series with `RMRB_Analysis`. Core component scripts stored in `RMRBCore` (`RMRB_AD.py`, `RMRB_Error.py`, `RMRB_Image.py`, `RMRB_LLM.py`, `RMRB_OCR.py`, `RMRB_PDF.py`)
# - (2025.10) Add Log system
# - (2026.1.8) Add new download link to downloader: https://1314955862-79a3hvoqxc-bj.scf.tencentcs.com/RMRB/{YEAR}/{YEAR}{MONTH}{DAY}.pdf (Before 2023)
# - (2026.1~2026.2)
# - Work Flow
#   - → Get Original RMRB PDF (`RMRB_Downloader.py`)
#   - → Detect Advertisement by Computer Vision Technique (`RMRB_Image.py`)
#   - → Generate Advertisement Images to local (Full / Half) (`RMRB_PDF.py`)
#   - → Convert Images to Text using OCR (`RMRB_OCR.py`)
#   - → Use LLM to Classify Industry of Advertisement (`RMRB_LLM.py`)
# - API file format
#
# ```python
# MODEL = {
#     "NAME": {
#         "Models": [""],
#         "API": ["API-KEY"]
#     },
#     ...
# }
# ```
